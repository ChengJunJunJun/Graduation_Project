# %%
from torch.utils.data import Dataset
import numpy as np
import torch
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

data = np.load('data/32s.npy')
print(data.shape)
a = data[0:20,0,300]
print(a)
# Out:
# (32, 720, 320)
# [ 0.08234342  0.16878986 -0.06531582 -0.21297263 -0.01217469  0.22113581
#   0.12351266 -0.14259648 -0.18106377  0.02478453  0.14990572  0.05209872
#  -0.0782899  -0.06812842  0.02024341  0.05739602  0.02363198 -0.03355412
#  -0.06682854 -0.02622403]

# %%
r_values = np.linspace(1, 20, 20)
plt.figure(figsize=(10, 6))
plt.plot(r_values, a)
